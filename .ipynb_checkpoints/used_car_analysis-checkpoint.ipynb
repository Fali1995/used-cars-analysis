# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
ford_df = pd.read_csv("data/ford.csv")
nissan_df = pd.read_csv("data/nissan.csv")
toyota_df = pd.read_csv("data/toyota.csv")
honda_df = pd.read_csv("data/honda.csv")
kia_df = pd.read_csv("data/kia.csv")

full_df = pd.concat([ford_df, nissan_df, toyota_df, honda_df, kia_df])
full_df['year'] = full_df['year'].astype(object)

full_df['price'] = full_df['price'].replace('Not Priced', np.NAN)
full_df['price'] = pd.to_numeric(full_df["price"])
full_df["model"] = full_df["model"].str.strip()

# %%
full_df.head()
# Out:
#   brand             model  year    price   mileage  \
# 0  Ford         Fusion SE  2010   5238.0  153715.0
# 1  Ford  Fusion Hybrid SE  2014  11494.0   56446.0
# 2  Ford         Fusion SE  2015  10795.0   65942.0
# 3  Ford         Taurus SE  2018  15999.0    2269.0
# 4  Ford   Fusion Titanium  2017  19280.0   19642.0
#
#                        exterior_color  interior_color      fuel_type  \
# 0               Tuxedo Black Metallic  Charcoal Black  E85 Flex Fuel
# 1  Ruby Red Metallic Tinted Clearcoat            Dune         Hybrid
# 2                            Magnetic           Ebony       Gasoline
# 3                 White Gold Metallic            Dune  E85 Flex Fuel
# 4                        Shadow Black           Ebony       Gasoline
#
#                                 engine       transmission  city_mpg  hwy_mpg
# 0              Gas/Ethanol V6 3.0L/181        6-Speed A/T      22.0     29.0
# 1         2.0L I4 16V MPFI DOHC Hybrid      Automatic CVT      44.0     41.0
# 2                2.5L I4 16V MPFI DOHC  6-Speed Automatic      22.0     31.0
# 3  3.5L V6 24V MPFI DOHC Flexible Fuel  6-Speed Automatic      18.0     27.0
# 4           2.0L I4 16V GDI DOHC Turbo  6-Speed Automatic      20.0     29.0

# %% [markdown]
# ### Mean Mileage per Year

# %%
mean_mileage_year = full_df.groupby("year")['mileage'].mean().round(0).astype(int)

plt.figure(figsize=(14,7))

plt.barh(mean_mileage_year.index, mean_mileage_year)
plt.yticks(mean_mileage_year.index)

plt.title("Mean Mileage by Year", fontsize=16)
plt.xlabel("Mileage", fontsize=15)
plt.ylabel("Year", fontsize=15)

plt.xlim([0,115000])

for year, miles in zip(mean_mileage_year.index, mean_mileage_year):
    plt.text(miles + 250, year - .125, miles)


plt.show()

# %% [markdown]
# ### Mean Price per Brand

# %%
plt.figure(figsize=(10,7))

width = .2

years = [2016, 2017, 2018, 2019]

for bar in range(len(years)): 
    price_plot = full_df[full_df["year"] == years[bar]].groupby("brand")["price"].mean().round(0).astype(int).sort_index()
    
    plt.bar(np.arange(5) + width*bar, price_plot, label=f"{years[bar]}", width=width)
    
    
plt.title("Mean Price of Cars per year", fontsize=16)
plt.xlabel("Car Brand", fontsize=14)
plt.ylabel("Price", fontsize=15)

plt.legend()
plt.xticks(np.arange(5) + .25, price_plot.index)

plt.show()

# %% [markdown]
# ### Exterior Color Price

# %%
car_models = ["Fusion SE", "Camry SE", "Accord Sport", "Forte LX", "Sentra SV"]
brands = ["Ford", "Toyota", "Honda", "Kia", "Nissan"]

df_plot = full_df[(full_df["model"].isin(car_models)) & (full_df["year"] == 2017)]

plt.figure(figsize=(12,30))


for ind in range(5):
    colors = df_plot[df_plot["model"] == car_models[ind]]["exterior_color"].value_counts()
    colors = colors[colors >= 15].index

    plot_values = df_plot[df_plot["model"] == car_models[ind]].groupby("exterior_color")['price'].mean().reindex(colors).\
                    round(0).astype(int)
                        
    plt.subplot(5,1,ind+1)
    
    plt.barh(plot_values.index, plot_values, color="teal")
    
    plt.title(f"Mean Price of 2017 {brands[ind]} {car_models[ind]} for Each Color", fontsize=16)
    plt.xlabel("Price", fontsize=14)
    plt.ylabel("Exterior Color", fontsize=15)
    
    plt.xlim([0, plot_values.max()+1500])
    
    for index, price in enumerate(plot_values):
        plt.text(price + 250, index - .125, price)
    
plt.subplots_adjust(top=1.1)

plt.show()

# %% [markdown]
# ### Price Change of Car Model per Year

# %%
top_models = full_df["model"].value_counts().index[:5]
brands = ["Ford", "Kia", "Nissan", "Honda", "Corolla"]

plt.figure(figsize=(12,30))


for ind in range(5):
    year_price = full_df[full_df["model"] == top_models[ind]].groupby("year")["price"].mean().round(0).astype(int)
    price_std = full_df[full_df["model"] == top_models[ind]].groupby("year")["price"].std().round(0).astype(int)
    
    plt.subplot(5,1,ind+1)
    
    plt.barh(year_price.index, year_price, color="coral")
    plt.yticks(year_price.index)
    
    plt.title(f"Mean Price of {brands[ind]} {car_models[ind]} for Each Year", fontsize=16)
    plt.xlabel("Price", fontsize=14)
    plt.ylabel("Year", fontsize=15)
    
    plt.xlim([0, year_price.max()+5000])
    
    for year, price, SD in zip(year_price.index, year_price, price_std):
        plt.text(price + 250, year - .125, f"Mean: {price},  SD: {SD}")

    
plt.subplots_adjust(top=1.05)
plt.show()

# %% [markdown]
# ### Fuel Type Prices

# %%
fuel_types = ['Gasoline', 'Hybrid']
fuel_df = full_df[(full_df["year"] == 2018) & (full_df["fuel_type"].isin(fuel_types))]
brands = ["Ford", "Toyota", "Honda", "Kia", "Nissan"]

width = .8/len(fuel_types)

plt.figure(figsize=(12,7))

for bar in range(len(fuel_types)):
    fuel_plot = fuel_df[fuel_df["fuel_type"] == fuel_types[bar]].groupby("brand")["price"].\
                                                                 mean().round(0).reindex(brands)
    
    fuel_plot = fuel_plot.replace(np.nan, 0)
    
    plt.bar(np.arange(len(fuel_plot)) + bar*width, fuel_plot, width=width, label=fuel_types[bar])

plt.title(f"Price Differences between Fuel Types", fontsize=16)
plt.ylabel("Price", fontsize=14)
plt.xlabel("brand", fontsize=15)

plt.xticks(np.arange(5) + width/2, brands)
plt.legend()

plt.show()

# %% [markdown]
# ### Miles per Gallon vs Price

# %%
df_2018 = full_df[full_df["year"] == 2018]

brands = ["Ford", "Toyota", "Honda", "Kia", "Nissan"]

plt.figure(figsize=(12,30))

for ind, brand in enumerate(brands):
    plt.subplot(5,1,ind+1)
    
    df_2018[df_2018["brand"] == brand].groupby("city_mpg")["price"].mean().plot(label = "City MPG")
    df_2018[df_2018["brand"] == brand].groupby("hwy_mpg")["price"].mean().plot(label = "Highway MPG")
    
    plt.title(f"{brand} Mean Price per MPG", fontsize=16)
    plt.xlabel("Miles per Gallon", fontsize=14)
    plt.ylabel("Mean Price", fontsize=15)
    
    plt.legend(loc=3)
    plt.grid()
    
plt.subplots_adjust(top=1.1)

plt.show()

# %% [markdown]
# ### Price per Engine

# %%
df_2018 = full_df[full_df["year"] == 2018]
brands = ["Ford", "Toyota", "Honda", "Kia", "Nissan"]

plt.figure(figsize=(12,30))

width = .25

for ind in range(len(brands)):
    brand_df = df_2018[df_2018["brand"] == brands[ind]]

    top_engines = brand_df["engine"].value_counts()
    top_engines = top_engines[top_engines >= 50].index
    
    plt.subplot(5,1,ind+1)
    
    top_25 = brand_df[brand_df["engine"].isin(top_engines)].groupby("engine")["price"].quantile(.25)
    top_50 = brand_df[brand_df["engine"].isin(top_engines)].groupby("engine")["price"].quantile(.50)
    top_75 = brand_df[brand_df["engine"].isin(top_engines)].groupby("engine")["price"].quantile(.75)
    
    plt.bar(np.arange(len(top_engines)), top_25, width=width, color="teal", label="25%")
    plt.bar(np.arange(len(top_engines)) + width, top_50, width=width, color="coral", label="50%")
    plt.bar(np.arange(len(top_engines)) + width*2, top_75, width=width, color="limegreen", label="75%")
    
    plt.xticks(np.arange(len(top_engines)) + width, top_engines, rotation=0, fontsize=9)
    
    plt.title(f"{brands[ind]}", fontsize=16)
    plt.xlabel("Engine", fontsize=14)
    plt.ylabel("Price", fontsize=15)
    
    plt.legend(loc=2)
    
plt.tight_layout()

# %% [markdown]
# ### Price per Transmission

# %%
df_2018 = full_df[full_df["year"] == 2018]
brands = ["Ford", "Toyota", "Honda", "Kia", "Nissan"]

plt.figure(figsize=(12,30))

width = .25

for ind in range(len(brands)):
    brand_df = df_2018[df_2018["brand"] == brands[ind]]

    top_transmissions = brand_df["transmission"].value_counts()
    top_transmissions = top_transmissions[:5].index
    
    plt.subplot(5,1,ind+1)
    
    top_25 = brand_df[brand_df["transmission"].isin(top_transmissions)].groupby("transmission")["price"].quantile(.25)
    top_50 = brand_df[brand_df["transmission"].isin(top_transmissions)].groupby("transmission")["price"].quantile(.50)
    top_75 = brand_df[brand_df["transmission"].isin(top_transmissions)].groupby("transmission")["price"].quantile(.75)
    
    plt.bar(np.arange(len(top_transmissions)), top_25, width=width, color="teal", label="25%")
    plt.bar(np.arange(len(top_transmissions)) + width, top_50, width=width, color="coral", label="50%")
    plt.bar(np.arange(len(top_transmissions)) + width*2, top_75, width=width, color="limegreen", label="75%")
    
    plt.xticks(np.arange(len(top_transmissions)) + width, top_transmissions, rotation=0, fontsize=8)
    
    plt.title(f"{brands[ind]}", fontsize=16)
    plt.xlabel("Transmission", fontsize=14)
    plt.ylabel("Price", fontsize=15)
    
    plt.legend(loc=2)
    
plt.tight_layout()

# %% [markdown]
# ### Mileage vs Price

# %%
top_models = full_df["model"].value_counts()

top_models = top_models[top_models >= 100].sample(5).index

plt.figure(figsize=(12,30))

for ind in range(len(top_models)):
    plt.subplot(5,1,ind+1)
    
    scatter_data = full_df[(full_df["model"] == top_models[ind])]
    
    plt.scatter(scatter_data["mileage"], scatter_data["price"], color="green")
    
    plt.title(f"{top_models[ind]}", fontsize=16)
    plt.xlabel("Mileage", fontsize=14)
    plt.ylabel("Price", fontsize=15)
    
    plt.xlim([-3000, scatter_data["mileage"].max() + 3000])
    plt.ylim([0, scatter_data["price"].max() + 1000])
    
    corr = scatter_data.corr().loc["price", "mileage"].round(4)
    
    plt.text(scatter_data["mileage"].max() + 3500, scatter_data["price"].max()/2, f"Correlation: {corr}", fontsize=13)
    
plt.subplots_adjust(top=1.05)

# %% [markdown]
# # Price Prediction

# %%
rmse_results = {}
mae_results = {}
r2_results = {}

car_models = full_df["model"].value_counts()

car_models = car_models[car_models >= 50].index

data = full_df[(full_df["model"].isin(car_models))][["model", "mileage", "year", "price"]].dropna()

X = data[["model", "year", "mileage"]]
y = data["price"]

X_encoded = pd.get_dummies(X, columns=["model"])

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=.3)

# %% [markdown]
# ### Linear Regression

# %%
model_lr = LinearRegression()
model_lr.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
prediction = model_lr.predict(X_test)

r2 = r2_score(y_test, prediction)
mse = mean_squared_error(y_test, prediction)
mae = mean_absolute_error(y_test, prediction)

rmse_results["Linear Regression"] = mse**.5
mae_results["Linear Regression"] = mae
r2_results["Linear Regression"] = r2

print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {mse**.5}")
print(f"Mean Absolute Error: {mae}")
print(f"R-Squared: {r2}")
# Out:
# Mean Squared Error: 2819819.831796951
# Root Mean Squared Error: 1679.2319172160082
# Mean Absolute Error: 1207.7159514983477
# R-Squared: 0.8550041980601554

# %% [markdown]
# ### K-Nearest Neighbors

# %%
warnings.filterwarnings('ignore')

X_scaler = StandardScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

model_knn = KNeighborsRegressor(n_neighbors=10)
model_knn.fit(X_train_scaled, y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#           weights='uniform')

# %%
prediction = model_knn.predict(X_test_scaled)

r2 = r2_score(y_test, prediction)
mse = mean_squared_error(y_test, prediction)
mae = mean_absolute_error(y_test, prediction)

rmse_results["K-Nearest Neighbors"] = mse**.5
mae_results["K-Nearest Neighbors"] = mae
r2_results["K-Nearest Neighbors"] = r2

print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {mse**.5}")
print(f"Mean Absolute Error: {mae}")
print(f"R-Squared: {r2}")
# Out:
# Mean Squared Error: 2159536.545171011
# Root Mean Squared Error: 1469.5361666767549
# Mean Absolute Error: 1029.5590176284466
# R-Squared: 0.8889561206518887

# %% [markdown]
# ### Decision Tree Regression

# %%
model_tree = DecisionTreeRegressor()
model_tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
prediction = model_tree.predict(X_test)

r2 = r2_score(y_test, prediction)
mse = mean_squared_error(y_test, prediction)
mae = mean_absolute_error(y_test, prediction)

rmse_results["Decision Tree"] = mse**.5
mae_results["Decision Tree"] = mae
r2_results["Decision Tree"] = r2

print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {mse**.5}")
print(f"Mean Absolute Error: {mae}")
print(f"R-Squared: {r2}")
# Out:
# Mean Squared Error: 3772940.004253302
# Root Mean Squared Error: 1942.4057259628592
# Mean Absolute Error: 1336.755122796444
# R-Squared: 0.8059945336156424

# %% [markdown]
# ### Random Forest Regressor

# %%
model_rf =  RandomForestRegressor(n_estimators=25)
model_rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=25, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
prediction = model_rf.predict(X_test)

r2 = r2_score(y_test, prediction)
mse = mean_squared_error(y_test, prediction)
mae = mean_absolute_error(y_test, prediction)

rmse_results["Random Forest"] = mse**.5
mae_results["Random Forest"] = mae
r2_results["Random Forest"] = r2

print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {mse**.5}")
print(f"Mean Absolute Error: {mae}")
print(f"R-Squared: {r2}")
# Out:
# Mean Squared Error: 2482774.230092402
# Root Mean Squared Error: 1575.6821475451202
# Mean Absolute Error: 1117.8631106351836
# R-Squared: 0.8723351625275929

# %% [markdown]
# ### Neural Network

# %%
X_scaler = StandardScaler().fit(X_train[:2])
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

model_nn = Sequential()

model_nn.add(Dense(units=25, activation='relu', input_dim=len(X_train.columns)))
model_nn.add(Dense(units=25, activation='relu',))
model_nn.add(Dense(units=25, activation='relu',))
model_nn.add(Dense(units=25, activation='relu',))

model_nn.add(Dense(units=1))

# %%
model_nn.compile(optimizer='adam',
              loss='mean_squared_error',
              metrics=['mean_absolute_error', 'mean_squared_error'])

# %%
model_nn.fit(
    X_train_scaled,
    y_train,
    epochs = 100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
#  - 1s - loss: 118641110.7365 - mean_absolute_error: 8493.1699 - mean_squared_error: 118641096.0000
# Epoch 2/100
#  - 1s - loss: 12601576.7823 - mean_absolute_error: 2288.0330 - mean_squared_error: 12601580.0000
# Epoch 3/100
#  - 1s - loss: 8243221.0040 - mean_absolute_error: 1708.3480 - mean_squared_error: 8243222.5000
# Epoch 4/100
#  - 1s - loss: 6329165.0129 - mean_absolute_error: 1433.7686 - mean_squared_error: 6329163.5000
# Epoch 5/100
#  - 1s - loss: 5504744.1299 - mean_absolute_error: 1329.3055 - mean_squared_error: 5504744.0000
# Epoch 6/100
#  - 1s - loss: 4932415.8588 - mean_absolute_error: 1273.2228 - mean_squared_error: 4932414.5000
# Epoch 7/100
#  - 1s - loss: 4468773.7193 - mean_absolute_error: 1226.6367 - mean_squared_error: 4468773.5000
# Epoch 8/100
#  - 1s - loss: 4147582.4706 - mean_absolute_error: 1183.9365 - mean_squared_error: 4147583.7500
# Epoch 9/100
#  - 1s - loss: 3969255.5606 - mean_absolute_error: 1155.7234 - mean_squared_error: 3969253.7500
# Epoch 10/100
#  - 1s - loss: 3866574.7135 - mean_absolute_error: 1130.1067 - mean_squared_error: 3866574.7500
# Epoch 11/100
#  - 1s - loss: 3823021.2010 - mean_absolute_error: 1120.5409 - mean_squared_error: 3823021.5000
# Epoch 12/100
#  - 1s - loss: 3795940.1859 - mean_absolute_error: 1112.7251 - mean_squared_error: 3795940.2500
# Epoch 13/100
#  - 1s - loss: 3777405.2531 - mean_absolute_error: 1109.3866 - mean_squared_error: 3777404.2500
# Epoch 14/100
#  - 1s - loss: 3771829.8436 - mean_absolute_error: 1107.5781 - mean_squared_error: 3771828.0000
# Epoch 15/100
#  - 1s - loss: 3756760.0694 - mean_absolute_error: 1103.9951 - mean_squared_error: 3756759.5000
# Epoch 16/100
#  - 1s - loss: 3732010.0334 - mean_absolute_error: 1094.2175 - mean_squared_error: 3732010.2500
# Epoch 17/100
#  - 1s - loss: 3725300.1671 - mean_absolute_error: 1093.0640 - mean_squared_error: 3725301.0000
# Epoch 18/100
#  - 1s - loss: 3716091.7552 - mean_absolute_error: 1093.8497 - mean_squared_error: 3716094.0000
# Epoch 19/100
#  - 1s - loss: 3715812.4439 - mean_absolute_error: 1094.0721 - mean_squared_error: 3715811.5000
# Epoch 20/100
#  - 1s - loss: 3700066.3691 - mean_absolute_error: 1086.1990 - mean_squared_error: 3700068.0000
# Epoch 21/100
#  - 1s - loss: 3703383.8292 - mean_absolute_error: 1086.6272 - mean_squared_error: 3703384.2500
# Epoch 22/100
#  - 1s - loss: 3694770.9884 - mean_absolute_error: 1084.4991 - mean_squared_error: 3694771.7500
# Epoch 23/100
#  - 1s - loss: 3682235.1175 - mean_absolute_error: 1080.8899 - mean_squared_error: 3682235.2500
# Epoch 24/100
#  - 1s - loss: 3672406.6686 - mean_absolute_error: 1081.2277 - mean_squared_error: 3672405.5000
# Epoch 25/100
#  - 1s - loss: 3667440.5349 - mean_absolute_error: 1079.3229 - mean_squared_error: 3667440.0000
# Epoch 26/100
#  - 1s - loss: 3657022.9982 - mean_absolute_error: 1074.5065 - mean_squared_error: 3657021.7500
# Epoch 27/100
#  - 1s - loss: 3654239.8092 - mean_absolute_error: 1074.3409 - mean_squared_error: 3654237.5000
# Epoch 28/100
#  - 1s - loss: 3649159.4709 - mean_absolute_error: 1073.4590 - mean_squared_error: 3649160.2500
# Epoch 29/100
#  - 1s - loss: 3642131.2360 - mean_absolute_error: 1071.4452 - mean_squared_error: 3642133.7500
# Epoch 30/100
#  - 1s - loss: 3633151.9539 - mean_absolute_error: 1069.4031 - mean_squared_error: 3633151.7500
# Epoch 31/100
#  - 1s - loss: 3638643.6258 - mean_absolute_error: 1073.0107 - mean_squared_error: 3638642.2500
# Epoch 32/100
#  - 1s - loss: 3621143.2528 - mean_absolute_error: 1065.6794 - mean_squared_error: 3621144.7500
# Epoch 33/100
#  - 1s - loss: 3627821.9507 - mean_absolute_error: 1070.6525 - mean_squared_error: 3627820.7500
# Epoch 34/100
#  - 1s - loss: 3628257.8351 - mean_absolute_error: 1066.6135 - mean_squared_error: 3628257.7500
# Epoch 35/100
#  - 1s - loss: 3620767.0378 - mean_absolute_error: 1063.8542 - mean_squared_error: 3620765.2500
# Epoch 36/100
#  - 1s - loss: 3624791.5719 - mean_absolute_error: 1066.7772 - mean_squared_error: 3624791.2500
# Epoch 37/100
#  - 1s - loss: 3603342.5684 - mean_absolute_error: 1060.6554 - mean_squared_error: 3603343.5000
# Epoch 38/100
#  - 1s - loss: 3614347.8646 - mean_absolute_error: 1061.9130 - mean_squared_error: 3614347.5000
# Epoch 39/100
#  - 1s - loss: 3594185.3221 - mean_absolute_error: 1057.4069 - mean_squared_error: 3594186.7500
# Epoch 40/100
#  - 1s - loss: 3597340.2937 - mean_absolute_error: 1059.4711 - mean_squared_error: 3597340.5000
# Epoch 41/100
#  - 1s - loss: 3596468.6837 - mean_absolute_error: 1057.6564 - mean_squared_error: 3596468.2500
# Epoch 42/100
#  - 1s - loss: 3586919.3122 - mean_absolute_error: 1055.2061 - mean_squared_error: 3586916.7500
# Epoch 43/100
#  - 1s - loss: 3587266.6003 - mean_absolute_error: 1057.4933 - mean_squared_error: 3587267.7500
# Epoch 44/100
#  - 1s - loss: 3581111.9631 - mean_absolute_error: 1052.1646 - mean_squared_error: 3581112.7500
# Epoch 45/100
#  - 1s - loss: 3581230.6691 - mean_absolute_error: 1052.3787 - mean_squared_error: 3581232.7500
# Epoch 46/100
#  - 1s - loss: 3578185.1405 - mean_absolute_error: 1050.8439 - mean_squared_error: 3578184.5000
# Epoch 47/100
#  - 1s - loss: 3573463.9762 - mean_absolute_error: 1052.5820 - mean_squared_error: 3573465.2500
# Epoch 48/100
#  - 1s - loss: 3573546.5035 - mean_absolute_error: 1052.3634 - mean_squared_error: 3573545.2500
# Epoch 49/100
#  - 1s - loss: 3574350.2207 - mean_absolute_error: 1049.2671 - mean_squared_error: 3574348.7500
# Epoch 50/100
#  - 1s - loss: 3575856.0035 - mean_absolute_error: 1048.4960 - mean_squared_error: 3575856.5000
# Epoch 51/100
#  - 1s - loss: 3567748.7493 - mean_absolute_error: 1049.7623 - mean_squared_error: 3567748.5000
# Epoch 52/100
#  - 1s - loss: 3557851.9700 - mean_absolute_error: 1047.5776 - mean_squared_error: 3557850.7500
# Epoch 53/100
#  - 1s - loss: 3551051.2492 - mean_absolute_error: 1045.4510 - mean_squared_error: 3551050.7500
# Epoch 54/100
#  - 1s - loss: 3556948.7109 - mean_absolute_error: 1044.0195 - mean_squared_error: 3556949.7500
# Epoch 55/100
#  - 1s - loss: 3556083.3591 - mean_absolute_error: 1048.4779 - mean_squared_error: 3556083.2500
# Epoch 56/100
#  - 1s - loss: 3553031.5140 - mean_absolute_error: 1047.8286 - mean_squared_error: 3553031.0000
# Epoch 57/100
#  - 1s - loss: 3564831.2350 - mean_absolute_error: 1048.0575 - mean_squared_error: 3564830.5000
# Epoch 58/100
#  - 1s - loss: 3543327.5852 - mean_absolute_error: 1044.1710 - mean_squared_error: 3543329.0000
# Epoch 59/100
#  - 1s - loss: 3545031.4527 - mean_absolute_error: 1043.7721 - mean_squared_error: 3545030.5000
# Epoch 60/100
#  - 1s - loss: 3550691.6472 - mean_absolute_error: 1048.0110 - mean_squared_error: 3550690.5000
# Epoch 61/100
#  - 1s - loss: 3547063.6060 - mean_absolute_error: 1046.3634 - mean_squared_error: 3547063.7500
# Epoch 62/100
#  - 1s - loss: 3543315.0096 - mean_absolute_error: 1042.8455 - mean_squared_error: 3543314.5000
# Epoch 63/100
#  - 1s - loss: 3543560.5932 - mean_absolute_error: 1044.7334 - mean_squared_error: 3543560.7500
# Epoch 64/100
#  - 1s - loss: 3541952.9409 - mean_absolute_error: 1042.1965 - mean_squared_error: 3541952.5000
# Epoch 65/100
#  - 1s - loss: 3541222.8697 - mean_absolute_error: 1044.0272 - mean_squared_error: 3541223.2500
# Epoch 66/100
#  - 1s - loss: 3534180.1611 - mean_absolute_error: 1039.0585 - mean_squared_error: 3534180.0000
# Epoch 67/100
#  - 1s - loss: 3533904.1850 - mean_absolute_error: 1040.2721 - mean_squared_error: 3533904.0000
# Epoch 68/100
#  - 1s - loss: 3536209.6992 - mean_absolute_error: 1041.5647 - mean_squared_error: 3536209.7500
# Epoch 69/100
#  - 1s - loss: 3535914.1538 - mean_absolute_error: 1041.9628 - mean_squared_error: 3535914.2500
# Epoch 70/100
#  - 1s - loss: 3530736.2335 - mean_absolute_error: 1040.0183 - mean_squared_error: 3530735.7500
# Epoch 71/100
#  - 1s - loss: 3525315.0280 - mean_absolute_error: 1037.2045 - mean_squared_error: 3525315.2500
# Epoch 72/100
#  - 1s - loss: 3521172.8219 - mean_absolute_error: 1038.7159 - mean_squared_error: 3521173.0000
# Epoch 73/100
#  - 1s - loss: 3528245.1103 - mean_absolute_error: 1040.5690 - mean_squared_error: 3528243.5000
# Epoch 74/100
#  - 1s - loss: 3527017.3524 - mean_absolute_error: 1039.1244 - mean_squared_error: 3527016.7500
# Epoch 75/100
#  - 1s - loss: 3528746.3185 - mean_absolute_error: 1040.5264 - mean_squared_error: 3528747.7500
# Epoch 76/100
#  - 1s - loss: 3526592.3210 - mean_absolute_error: 1037.0680 - mean_squared_error: 3526591.2500
# Epoch 77/100
#  - 1s - loss: 3526502.9566 - mean_absolute_error: 1039.3567 - mean_squared_error: 3526502.7500
# Epoch 78/100
#  - 1s - loss: 3522069.6710 - mean_absolute_error: 1038.1135 - mean_squared_error: 3522069.7500
# Epoch 79/100
#  - 1s - loss: 3510503.5160 - mean_absolute_error: 1036.0179 - mean_squared_error: 3510503.7500
# Epoch 80/100
#  - 1s - loss: 3513296.9355 - mean_absolute_error: 1034.9445 - mean_squared_error: 3513297.0000
# Epoch 81/100
#  - 1s - loss: 3526036.2304 - mean_absolute_error: 1039.7567 - mean_squared_error: 3526036.7500
# Epoch 82/100
#  - 1s - loss: 3511445.4333 - mean_absolute_error: 1034.7006 - mean_squared_error: 3511444.2500
# Epoch 83/100
#  - 1s - loss: 3518850.8136 - mean_absolute_error: 1036.6685 - mean_squared_error: 3518852.5000
# Epoch 84/100
#  - 1s - loss: 3512094.2564 - mean_absolute_error: 1034.5852 - mean_squared_error: 3512095.5000
# Epoch 85/100
#  - 1s - loss: 3526245.9209 - mean_absolute_error: 1042.2046 - mean_squared_error: 3526246.2500
# Epoch 86/100
#  - 1s - loss: 3516964.1624 - mean_absolute_error: 1035.5192 - mean_squared_error: 3516966.0000
# Epoch 87/100
#  - 1s - loss: 3511898.1252 - mean_absolute_error: 1035.5764 - mean_squared_error: 3511897.0000
# Epoch 88/100
#  - 1s - loss: 3514638.3065 - mean_absolute_error: 1035.5905 - mean_squared_error: 3514637.7500
# Epoch 89/100
#  - 1s - loss: 3506970.6193 - mean_absolute_error: 1034.3966 - mean_squared_error: 3506970.0000
# Epoch 90/100
#  - 1s - loss: 3515675.9160 - mean_absolute_error: 1035.2942 - mean_squared_error: 3515676.2500
# Epoch 91/100
#  - 1s - loss: 3521761.7331 - mean_absolute_error: 1037.3380 - mean_squared_error: 3521762.0000
# Epoch 92/100
#  - 1s - loss: 3517106.3962 - mean_absolute_error: 1035.8314 - mean_squared_error: 3517105.5000
# Epoch 93/100
#  - 1s - loss: 3511198.1419 - mean_absolute_error: 1036.0093 - mean_squared_error: 3511198.2500
# Epoch 94/100
#  - 1s - loss: 3511505.8538 - mean_absolute_error: 1035.0597 - mean_squared_error: 3511504.0000
# Epoch 95/100
#  - 1s - loss: 3512814.8195 - mean_absolute_error: 1037.3239 - mean_squared_error: 3512814.0000
# Epoch 96/100
#  - 1s - loss: 3504553.6160 - mean_absolute_error: 1031.5149 - mean_squared_error: 3504554.0000
# Epoch 97/100
#  - 1s - loss: 3509122.3935 - mean_absolute_error: 1036.4281 - mean_squared_error: 3509121.7500
# Epoch 98/100
#  - 1s - loss: 3512121.5690 - mean_absolute_error: 1035.7611 - mean_squared_error: 3512122.2500
# Epoch 99/100
#  - 1s - loss: 3505306.0450 - mean_absolute_error: 1034.0549 - mean_squared_error: 3505305.5000
# Epoch 100/100
#  - 1s - loss: 3510492.7338 - mean_absolute_error: 1031.3390 - mean_squared_error: 3510493.5000

# %%
prediction = model_nn.predict(X_test_scaled)

r2 = r2_score(y_test, prediction)
mse = mean_squared_error(y_test, prediction)
mae = mean_absolute_error(y_test, prediction)

rmse_results["Neural Network"] = mse**.5
mae_results["Neural Network"] = mae
r2_results["Neural Network"] = r2

print(f"Mean Squared Error: {mse}")
print(f"Root Mean Squared Error: {mse**.5}")
print(f"Mean Absolute Error: {mae}")
print(f"R-Squared: {r2}")
# Out:
# Mean Squared Error: 1983038.908635405
# Root Mean Squared Error: 1408.2041430969464
# Mean Absolute Error: 1040.5850974090563
# R-Squared: 0.8980316708205174

# %% [markdown]
# ## Results

# %%
rmse_list = pd.Series(rmse_results).round(0).astype(int)
mae_list = pd.Series(mae_results).round(0).astype(int)
r2_list = pd.Series(r2_results).round(4)

results = pd.concat([rmse_list, mae_list, r2_list], 1)
results.columns = ["Root Mean Squared Error", "Mean Absolute Error", "R-Squared"] 

plt.figure(figsize=(12,18))

for ind in range(3):
    plt.subplot(3,1, ind+1)
    results.iloc[:,ind].plot(kind='bar', color="seagreen")
    
    plt.title(f"{results.columns[ind]}", fontsize=15)
    plt.xlabel("Machine Learning Algorithm", fontsize=14)
    plt.ylabel("Score", fontsize=14)
    
    plt.xticks(rotation = 0, fontsize=11)

    for val in range(5):
        plt.text(val-.1, results.iloc[val,ind] * 1.01, results.iloc[val,ind])

plt.subplots_adjust(top=1.1)
